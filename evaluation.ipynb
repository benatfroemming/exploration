# %% [markdown]
# # Evaluation

# %%
# !git clone https://github.com/benatfroemming/exploration.git
# %cd exploration
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Inference

# %% [markdown]
# Epsilon Greedy - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/epsilon_greedy_42_s2000000.pth" --strategy epsilon_greedy --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/epsilon_greedy_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: epsilon_greedy
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/epsilon_greedy_42_s2000000.pth
# Total reward: 143.0
# Total steps: 200000

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/epsilon_greedy_84_s2000000.pth" --strategy epsilon_greedy --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/epsilon_greedy_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: epsilon_greedy
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/epsilon_greedy_84_s2000000.pth
# Total reward: 216.0
# Total steps: 200000

# %% [markdown]
# Boltzmann - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/boltzmann_42_s2000000.pth" --strategy boltzmann --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/boltzmann_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: boltzmann
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/boltzmann_42_s2000000.pth
# Total reward: 93.0
# Total steps: 200000

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/boltzmann_84_s2000000.pth" --strategy boltzmann --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/boltzmann_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: boltzmann
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/boltzmann_84_s2000000.pth
# Total reward: 407.0
# Total steps: 126791

# %% [markdown]
# Entropy Reg. - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/entropy_reg_42_s2000000.pth" --strategy entropy_reg --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/entropy_reg_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: entropy_reg
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/entropy_reg_42_s2000000.pth
# Total reward: 114.0
# Total steps: 200000

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/entropy_reg_84_s2000000.pth" --strategy entropy_reg --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/entropy_reg_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: entropy_reg
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/entropy_reg_84_s2000000.pth
# Total reward: 310.0
# Total steps: 162509

# %% [markdown]
# UCB - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/ucb_42_s2000000.pth" --strategy ucb --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/ucb_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: ucb
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 92.0
# Total steps: 200000

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/ucb_84_s2000000.pth" --strategy ucb --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/ucb_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: ucb
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 83.0
# Total steps: 200000

# %% [markdown]
# Thompson - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/thompson_42_s2000000.pth" --strategy thompson --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/thompson_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: thompson
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 83.0
# Total steps: 200000

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/thompson_84_s2000000.pth" --strategy thompson --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/thompson_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: thompson
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 133.0
# Total steps: 200000

# %% [markdown]
# RND - Breakout

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/rnd_42_s2000000.pth" --strategy rnd --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/rnd_42_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: rnd
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 42/rnd_42_s2000000.pth
# Total reward: 268.0
# Total steps: 162276

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/rnd_84_s2000000.pth" --strategy rnd --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/rnd_84_s2000000.pth
# Env: ALE/Breakout-v5
# Strategy: rnd
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Breakout/Weights/Seed 84/rnd_84_s2000000.pth
# Total reward: 251.0
# Total steps: 181298

# %% [markdown]
# Epsilon Greedy - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/epsilon_greedy_42_s2000000.pth" --env ALE/Freeway-v5 --strategy epsilon_greedy --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/epsilon_greedy_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: epsilon_greedy
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/epsilon_greedy_42_s2000000.pth
# Total reward: 212.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/epsilon_greedy_84_s2000000.pth" --env ALE/Freeway-v5 --strategy epsilon_greedy --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/epsilon_greedy_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: epsilon_greedy
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/epsilon_greedy_84_s2000000.pth
# Total reward: 288.0
# Total steps: 20470

# %% [markdown]
# Boltzmann - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/boltzmann_42_s2000000.pth" --env ALE/Freeway-v5 --strategy boltzmann --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/boltzmann_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: boltzmann
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/boltzmann_42_s2000000.pth
# Total reward: 0.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/boltzmann_84_s2000000.pth" --env ALE/Freeway-v5 --strategy boltzmann --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/boltzmann_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: boltzmann
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/boltzmann_84_s2000000.pth
# Total reward: 0.0
# Total steps: 20470

# %% [markdown]
# Entropy Reg. - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/entropy_reg_42_s2000000.pth" --env ALE/Freeway-v5 --strategy entropy_reg --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/entropy_reg_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: entropy_reg
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/entropy_reg_42_s2000000.pth
# Total reward: 321.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/entropy_reg_84_s2000000.pth" --env ALE/Freeway-v5 --strategy entropy_reg --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/entropy_reg_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: entropy_reg
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/entropy_reg_84_s2000000.pth
# Total reward: 316.0
# Total steps: 20470

# %% [markdown]
# UCB - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/ucb_42_s2000000.pth" --env ALE/Freeway-v5 --strategy ucb --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/ucb_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: ucb
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 269.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/ucb_84_s2000000.pth" --env ALE/Freeway-v5 --strategy ucb --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/ucb_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: ucb
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 258.0
# Total steps: 20470

# %% [markdown]
# Thompson - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/thompson_42_s2000000.pth" --env ALE/Freeway-v5 --strategy thompson --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/thompson_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: thompson
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 313.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/thompson_84_s2000000.pth" --env ALE/Freeway-v5 --strategy thompson --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/thompson_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: thompson
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Total reward: 318.0
# Total steps: 20470

# %% [markdown]
# RND - Freeway

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/rnd_42_s2000000.pth" --env ALE/Freeway-v5 --strategy rnd --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/rnd_42_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: rnd
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 42/rnd_42_s2000000.pth
# Total reward: 319.0
# Total steps: 20470

# %%
# !python eval.py --policy "/content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/rnd_84_s2000000.pth" --env ALE/Freeway-v5 --strategy rnd --episodes 10
# Out:
# Device: cuda
# Policy: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/rnd_84_s2000000.pth
# Env: ALE/Freeway-v5
# Strategy: rnd
# Episodes: 10
#
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Loading checkpoint: /content/drive/MyDrive/Exploration/Trainings/Freeway/Weights/Seed 84/rnd_84_s2000000.pth
# Total reward: 320.0
# Total steps: 20470

# %% [markdown]
# ## Visualizations

# %%
# !python visualize.py --dir "/content/drive/MyDrive/Exploration/Trainings/Breakout/Logs" --title "Breakout-v5"
# Out:
# Scanning /content/drive/MyDrive/Exploration/Trainings/Breakout/Logs …
#   Found 12 run(s):
#     boltzmann_42_s2000000  (4675 records)
#     boltzmann_84_s2000000  (4719 records)
#     entropy_reg_42_s2000000  (3437 records)
#     entropy_reg_84_s2000000  (3529 records)
#     epsilon_greedy_42_s2000000  (3958 records)
#     epsilon_greedy_84_s2000000  (3974 records)
#     rnd_42_s2000000  (3232 records)
#     rnd_84_s2000000  (2686 records)
#     thompson_42_s2000000  (2511 records)
#     thompson_84_s2000000  (3496 records)
#     ucb_42_s2000000  (3472 records)
#     ucb_84_s2000000  (2974 records)
#   Built 6 chart(s): ['reward vs episode', 'reward vs total_steps', 'ep_len vs episode', 'loss vs total_steps', 'entropy vs total_steps', 'regret vs total_steps']
#   Saved → /content/exploration/breakout-v5.html

# %%
# !python visualize.py --dir "/content/drive/MyDrive/Exploration/Trainings/Freeway/Logs" --title "Freeway-v5"
# Out:
# Scanning /content/drive/MyDrive/Exploration/Trainings/Freeway/Logs …
#   Found 12 run(s):
#     boltzmann_42_s2000000  (956 records)
#     boltzmann_84_s2000000  (956 records)
#     entropy_reg_42_s2000000  (956 records)
#     entropy_reg_84_s2000000  (956 records)
#     epsilon_greedy_42_s2000000  (956 records)
#     epsilon_greedy_84_s2000000  (956 records)
#     rnd_42_s2000000  (956 records)
#     rnd_84_s2000000  (956 records)
#     thompson_42_s2000000  (956 records)
#     thompson_84_s2000000  (956 records)
#     ucb_42_s2000000  (956 records)
#     ucb_84_s2000000  (956 records)
#   Built 6 chart(s): ['reward vs episode', 'reward vs total_steps', 'ep_len vs episode', 'loss vs total_steps', 'entropy vs total_steps', 'regret vs total_steps']
#   Saved → /content/exploration/freeway-v5.html

# %% [markdown]
# # Epsilon Greedy
#
# Training on the Breakout environment for 5000 episodes using epsilon greedy.

# %%
# !nvidia-smi
# Out:
# Fri Mar 27 15:04:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/benatfroemming/exploration.git
# %cd exploration
# !pip install -r requirements.txt
# Out:
# Cloning into 'exploration'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 57 (delta 22), reused 52 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 481.95 KiB | 13.77 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /kaggle/working/exploration
# ...

# %%
# !python train.py --episodes 5000 --strategy epsilon_greedy --env ALE/Breakout-v5
# Out:
# Device  : cuda
# Env     : ALE/Breakout-v5
# Strategy: epsilon_greedy
# Episodes: 5000
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Run dir : runs/ALE-Breakout-v5/epsilon_greedy/20260327_150452
#
#   Filling replay buffer … 10,000/50,000 steps
#   Filling replay buffer … 20,000/50,000 steps
#   Filling replay buffer … 30,000/50,000 steps
#   Filling replay buffer … 40,000/50,000 steps
#   [target sync] step=50,000  ε=0.9550
#   [target sync] step=60,000  ε=0.9460
# [ep   100] steps=   67,378  reward=   1.0  ep_len=   148  ε=0.9394
#   [target sync] step=70,000  ε=0.9370
#   [target sync] step=80,000  ε=0.9280
# [ep   200] steps=   85,058  reward=   5.0  ep_len=   320  ε=0.9234
#   [target sync] step=90,000  ε=0.9190
#   [target sync] step=100,000  ε=0.9100
# [ep   300] steps=  102,698  reward=   2.0  ep_len=   217  ε=0.9076
#   [target sync] step=110,000  ε=0.9010
#   [target sync] step=120,000  ε=0.8920
# ...

# %%
# !apt-get install -y tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 133 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (158 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 124626 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree
# Out:
# .
# ├── core.py
# ├── exploration
# │   ├── epsilon_greedy.py
# │   └── __pycache__
# │       └── epsilon_greedy.cpython-312.pyc
# ├── __pycache__
# │   └── core.cpython-312.pyc
# ├── README.md
# ├── requirements.txt
# ├── results.ipynb
# ├── runs
# │   └── ALE-Breakout-v5
# │       └── epsilon_greedy
# │           └── 20260327_150452
# │               ├── dqn_ALE-Breakout-v5_epsilon_greedy_final.pth
# │               └── training_log.jsonl
# ├── training.ipynb
# └── train.py
#
# 7 directories, 11 files

# %% [markdown]
# Save policy and training log in Google Drive.
